# %% [markdown]
# <a href="https://colab.research.google.com/github/vtu30294-ai/AIT-LAB-TASK/blob/main/Task7_Monkey_Banana_Problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def monkey_banana():
    state = ["floor", "window", False]
    print("Initial State:", state)
    print("Monkey moves to box")
    state[0] = "window"
    print("Monkey pushes box to center")
    state[1] = "center"
    print("Monkey climbs box")
    state[2] = True
    if state[2] and state[1] == "center":
        print("Monkey touches bananas!")
        print("Goal Reached!")

monkey_banana()
# Out:
# Initial State: ['floor', 'window', False]
# Monkey moves to box
# Monkey pushes box to center
# Monkey climbs box
# Monkey touches bananas!
# Goal Reached!
